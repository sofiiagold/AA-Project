# %%
import pandas as pd

# %%
df = pd.read_csv('export.csv')

# %%
df
# Out:
#                      date  tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  \
# 0     2022-01-01 00:00:00  11.5   8.5  13.2   0.0   NaN   198  19.1  36.0
# 1     2022-01-02 00:00:00  11.6  10.0  12.7   6.8   NaN   219  31.7  72.0
# 2     2022-01-03 00:00:00   9.5   8.0  11.1   NaN   NaN   231  32.0  61.0
# 3     2022-01-04 00:00:00   6.8   3.7   8.7   0.7   NaN   271  16.7  50.0
# 4     2022-01-05 00:00:00   5.5   3.2   7.7   3.5   NaN   291  31.1  72.0
# ...                   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 1195  2025-04-10 00:00:00   9.1   5.0  13.0   0.0   NaN   328  17.0  36.0
# 1196  2025-04-11 00:00:00   9.8   3.5  16.1   0.0   NaN   269  12.0  30.0
# 1197  2025-04-12 00:00:00  14.5   6.0  22.3   0.0   NaN   105  15.0  43.0
# 1198  2025-04-13 00:00:00  14.2  11.4  17.7   3.7   NaN   225  23.0  43.0
# 1199  2025-04-14 00:00:00  12.7   9.1  16.2   0.1   NaN   186  13.6  32.0
#
#         pres  tsun
# 0     1020.5   NaN
# 1     1010.7   NaN
# ...

# %%
df = df.drop(columns = ['snow', 'tsun','wdir', 'wspd','wpgt','pres'])

# %%
df
# Out:
#                      date  tavg  tmin  tmax  prcp
# 0     2022-01-01 00:00:00  11.5   8.5  13.2   0.0
# 1     2022-01-02 00:00:00  11.6  10.0  12.7   6.8
# 2     2022-01-03 00:00:00   9.5   8.0  11.1   NaN
# 3     2022-01-04 00:00:00   6.8   3.7   8.7   0.7
# 4     2022-01-05 00:00:00   5.5   3.2   7.7   3.5
# ...                   ...   ...   ...   ...   ...
# 1195  2025-04-10 00:00:00   9.1   5.0  13.0   0.0
# 1196  2025-04-11 00:00:00   9.8   3.5  16.1   0.0
# 1197  2025-04-12 00:00:00  14.5   6.0  22.3   0.0
# 1198  2025-04-13 00:00:00  14.2  11.4  17.7   3.7
# 1199  2025-04-14 00:00:00  12.7   9.1  16.2   0.1
#
# [1200 rows x 5 columns]

# %%
df['date'] = pd.to_datetime(df['date']).dt.date

# %%
df
# Out:
#             date  tavg  tmin  tmax  prcp
# 0     2022-01-01  11.5   8.5  13.2   0.0
# 1     2022-01-02  11.6  10.0  12.7   6.8
# 2     2022-01-03   9.5   8.0  11.1   NaN
# 3     2022-01-04   6.8   3.7   8.7   0.7
# 4     2022-01-05   5.5   3.2   7.7   3.5
# ...          ...   ...   ...   ...   ...
# 1195  2025-04-10   9.1   5.0  13.0   0.0
# 1196  2025-04-11   9.8   3.5  16.1   0.0
# 1197  2025-04-12  14.5   6.0  22.3   0.0
# 1198  2025-04-13  14.2  11.4  17.7   3.7
# 1199  2025-04-14  12.7   9.1  16.2   0.1
#
# [1200 rows x 5 columns]

# %%
df = df.drop(columns =['tmin', 'tmax'] )

# %%
df
# Out:
#             date  tavg  prcp
# 0     2022-01-01  11.5   0.0
# 1     2022-01-02  11.6   6.8
# 2     2022-01-03   9.5   NaN
# 3     2022-01-04   6.8   0.7
# 4     2022-01-05   5.5   3.5
# ...          ...   ...   ...
# 1195  2025-04-10   9.1   0.0
# 1196  2025-04-11   9.8   0.0
# 1197  2025-04-12  14.5   0.0
# 1198  2025-04-13  14.2   3.7
# 1199  2025-04-14  12.7   0.1
#
# [1200 rows x 3 columns]

# %%
pd.set_option('display.max.rows', 1200)

# %%
df
# Out:
#             date  tavg  prcp
# 0     2022-01-01  11.5   0.0
# 1     2022-01-02  11.6   6.8
# 2     2022-01-03   9.5   NaN
# 3     2022-01-04   6.8   0.7
# 4     2022-01-05   5.5   3.5
# 5     2022-01-06   3.3   0.1
# 6     2022-01-07   4.2   2.8
# 7     2022-01-08   3.6  11.4
# 8     2022-01-09   5.2   6.3
# 9     2022-01-10   2.3   0.0
# 10    2022-01-11   2.4   0.7
# 11    2022-01-12   3.9   0.1
# 12    2022-01-13   5.5   0.0
# 13    2022-01-14   5.4   0.0
# 14    2022-01-15   3.0   0.0
# 15    2022-01-16   6.1   0.0
# 16    2022-01-17   6.8   0.0
# 17    2022-01-18   3.0   0.0
# 18    2022-01-19   4.8   NaN
# 19    2022-01-20   4.2   1.1
# 20    2022-01-21   4.4   0.9
# 21    2022-01-22   6.6   0.0
# 22    2022-01-23   6.3   0.0
# 23    2022-01-24   4.7   0.0
# 24    2022-01-25   3.2   0.0
# 25    2022-01-26   4.6   0.0
# 26    2022-01-27   7.4   2.1
# 27    2022-01-28   6.6   0.0
# 28    2022-01-29   9.3   0.0
# 29    2022-01-30   6.4   0.0
# 30    2022-01-31   5.9   7.1
# ...

# %%
df.isnull().sum().sum()
# Out:
# 40
